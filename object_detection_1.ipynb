# %%
import os

dataset_path = r"D:\AI_Diploma\Training tasks\Sprint_2\dataset"

for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 4 * (level + 1)
    for f in files[:3]:  # Show only the first 3 files in each folder
        print(f"{subindent}{f}")
# Out:
# dataset/
#     Calculus/
#         Calculus/
#             (1).jpg
#             (10).jpg
#             (100).jpg
#     Caries_Gingivitus_ToothDiscoloration_Ulcer-yolo_annotated-Dataset/
#         Caries_Gingivitus_ToothDiscoloration_Ulcer-yolo_annotated-Dataset/
#             Data/
#                 data.yaml
#                 images/
#                     train/
#                         (1).jpg
#                         (10).jpg
#                         (100).jpg
#                     val/
#                         (225).jpg
#                         (226).jpg
#                         (227).jpg
#                 labels/
#                     train/
#                         (1).txt
#                         (10).txt
#                         (100).txt
#                     val/
#                         (225).txt
#                         (226).txt
#                         (227).txt
#     Data caries/
#         Data caries/
#             caries augmented data set/
# ...

# %%
import os

dataset_path = r"D:\AI_Diploma\Training tasks\Sprint_2\dataset"

with open("dataset_structure.txt", "w", encoding="utf-8") as f:
    for root, dirs, files in os.walk(dataset_path):
        level = root.replace(dataset_path, "").count(os.sep)
        indent = "    " * level
        f.write(f"{indent}{os.path.basename(root)}/\n")

        for file in files:
            f.write(f"{indent}    {file}\n")

print("Done! Check dataset_structure.txt")
# Out:
# Done! Check dataset_structure.txt

# %%
import os

dataset_path = r"D:\AI_Diploma\Training tasks\Sprint_2\dataset"

print("Top-level folders:\n")

for folder in sorted(os.listdir(dataset_path)):
    full_path = os.path.join(dataset_path, folder)
    if os.path.isdir(full_path):
        print(folder)
# Out:
# Top-level folders:
#
# Calculus
# Caries_Gingivitus_ToothDiscoloration_Ulcer-yolo_annotated-Dataset
# Data caries
# Gingivitis
# Mouth Ulcer
# Tooth Discoloration
# hypodontia
